# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
#from matplotlib import interactive
#import PyQt5

# %matplotlib notebook

# %%
data = open('../Multiview_Action_3D_Dataset/dataset_full/Train/a09_s01_e01_skeleton_proj.txt')

# %%
frames = {}

for line in data:
    frame = line.split()
    frame = np.array([float(x) for x in frame])
    if frame[0] in frames:
        frames[frame[0]] = np.append(frames[frame[0]], np.array(frame[1:]))
    else:
        frames[frame[0]] = np.array(frame[1:])


for key in frames:
    frames[key] = frames[key].reshape((20, 4))

# %%
# each frame has data that looks like this
# joint num, x, y, z
frames[1]
# Out:
# array([[ 1.000e+00,  1.200e-02, -5.350e-01,  2.261e+00],
#        [ 2.000e+00,  1.300e-02, -4.680e-01,  2.249e+00],
#        [ 3.000e+00,  1.800e-02, -1.390e-01,  2.200e+00],
#        [ 4.000e+00,  3.100e-02,  6.800e-02,  2.171e+00],
#        [ 5.000e+00, -1.410e-01, -2.010e-01,  2.160e+00],
#        [ 6.000e+00, -1.800e-01, -3.770e-01,  2.043e+00],
#        [ 7.000e+00, -1.400e-02, -4.430e-01,  1.869e+00],
#        [ 8.000e+00,  4.100e-02, -4.660e-01,  1.815e+00],
#        [ 9.000e+00,  1.750e-01, -2.210e-01,  2.210e+00],
#        [ 1.000e+01,  2.390e-01, -3.920e-01,  2.091e+00],
#        [ 1.100e+01,  9.600e-02, -4.430e-01,  1.892e+00],
#        [ 1.200e+01,  5.500e-02, -4.830e-01,  1.792e+00],
#        [ 1.300e+01, -7.700e-02, -6.150e-01,  2.252e+00],
#        [ 1.400e+01, -1.630e-01, -4.940e-01,  1.957e+00],
#        [ 1.500e+01, -3.010e-01, -7.940e-01,  2.179e+00],
#        [ 1.600e+01, -4.100e-01, -8.200e-01,  2.180e+00],
#        [ 1.700e+01,  9.800e-02, -5.980e-01,  2.284e+00],
#        [ 1.800e+01,  2.240e-01, -4.770e-01,  2.007e+00],
#        [ 1.900e+01,  2.930e-01, -8.190e-01,  1.942e+00],
#        [ 2.000e+01,  3.080e-01, -8.710e-01,  1.857e+00]])

# %%
frame_num = 15
xs = frames[frame_num][:,1]
ys = frames[frame_num][:,2]
zs = frames[frame_num][:,3]

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
colors = ['blue' for i in range(20)]
colors[0] = 'red'
colors[7] = 'green'
colors[11] = 'green'
colors[15] = 'green'
colors[19] = 'green'
colors[3] = 'black'
ax.scatter(xs,ys,zs, color=colors)
for x, y, z, i in zip(xs, ys, zs, range(1,21)):
    ax.text(x,y,z,i)
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
import sys
sys.path.append("../")
from Skeleton import Skeleton
import SkeletonNormalization as SN

# %%
frames[1]
# Out:
# array([[ 1.000e+00,  1.200e-02, -5.350e-01,  2.261e+00],
#        [ 2.000e+00,  1.300e-02, -4.680e-01,  2.249e+00],
#        [ 3.000e+00,  1.800e-02, -1.390e-01,  2.200e+00],
#        [ 4.000e+00,  3.100e-02,  6.800e-02,  2.171e+00],
#        [ 5.000e+00, -1.410e-01, -2.010e-01,  2.160e+00],
#        [ 6.000e+00, -1.800e-01, -3.770e-01,  2.043e+00],
#        [ 7.000e+00, -1.400e-02, -4.430e-01,  1.869e+00],
#        [ 8.000e+00,  4.100e-02, -4.660e-01,  1.815e+00],
#        [ 9.000e+00,  1.750e-01, -2.210e-01,  2.210e+00],
#        [ 1.000e+01,  2.390e-01, -3.920e-01,  2.091e+00],
#        [ 1.100e+01,  9.600e-02, -4.430e-01,  1.892e+00],
#        [ 1.200e+01,  5.500e-02, -4.830e-01,  1.792e+00],
#        [ 1.300e+01, -7.700e-02, -6.150e-01,  2.252e+00],
#        [ 1.400e+01, -1.630e-01, -4.940e-01,  1.957e+00],
#        [ 1.500e+01, -3.010e-01, -7.940e-01,  2.179e+00],
#        [ 1.600e+01, -4.100e-01, -8.200e-01,  2.180e+00],
#        [ 1.700e+01,  9.800e-02, -5.980e-01,  2.284e+00],
#        [ 1.800e+01,  2.240e-01, -4.770e-01,  2.007e+00],
#        [ 1.900e+01,  2.930e-01, -8.190e-01,  1.942e+00],
#        [ 2.000e+01,  3.080e-01, -8.710e-01,  1.857e+00]])

# %%
R = np.array([.5 for i in range(19)])
norm_skele = SN.normalize_skeleton(frames[15], R)
print(norm_skele)
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 3.45173294e-01  3.58449190e-01  4.86782850e-02]
#  [ 3.21058037e-01 -1.39932788e-01  8.08319610e-02]
#  [-8.58000583e-03  2.32239196e-01  2.76645348e-02]
#  [ 1.44077309e-01 -1.39160804e-04  4.43231669e-01]
#  [ 1.30757658e-01 -4.99626063e-01  4.61546189e-01]
#  [-1.38128043e-01 -7.30802184e-01  8.14048786e-01]
#  [ 3.38468540e-02 -3.52959527e-01  5.35374135e-01]
#  [ 5.17862757e-01 -3.12364645e-01  6.54036098e-01]
#  [ 4.88076686e-01 -8.08799149e-01  7.05665286e-01]
#  [-4.39517349e-04 -7.08668498e-01  6.69254141e-01]
#  [-8.28801256e-02 -2.23974578e-01  7.60223088e-01]
#  [ 4.04446261e-01 -1.12202471e-01  7.55752203e-01]
#  [ 4.95182221e-01  2.97272628e-01  1.02796008e+00]
#  [ 3.49195486e-01  6.91205088e-01  1.29907830e+00]
#  [ 2.77152941e-01  9.12478616e-01  1.74162536e+00]
#  [-5.24941343e-02  1.04514146e+00  2.09338291e+00]
#  [ 2.23813291e-01  1.15326176e+00  2.49583068e+00]
#  [-1.19267283e-01  1.29049399e+00  2.83267343e+00]
#  [ 7.31740073e-02  1.45299997e+00  3.26459721e+00]]

# %%
xs = norm_skele[:,0]
ys = norm_skele[:,1]
zs = norm_skele[:,2]
colors = ['blue' for i in range(20)]
colors[0] = 'red'
colors[7] = 'green'
colors[11] = 'green'
colors[15] = 'green'
colors[19] = 'green'
colors[3] = 'black'
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter(xs,ys,zs, color=colors)
for x, y, z, i in zip(xs, ys, zs, range(1, 21)):
    ax.text(x,y,z,i)
# Out:
# <img src="data:image/png;base64,..." width="639.85">
