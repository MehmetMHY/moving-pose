# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import interactive
import PyQt5

# %matplotlib notebook

# %%
data = open('Multiview_Action_3D_Dataset/dataset_full/Train/a02_s04_e01_skeleton_proj.txt')

# %%
frames = {}

for line in data:
    frame = line.split()
    frame = np.array([float(x) for x in frame])
    if frame[0] in frames:
        frames[frame[0]] = np.append(frames[frame[0]], np.array(frame[1:]))
    else:
        frames[frame[0]] = np.array(frame[1:])


for key in frames:
    frames[key] = frames[key].reshape((20, 4))

# %%
# each frame has data that looks like this
# joint num, x, y, z
frames[1]
# Out:
# array([[ 1.000e+00,  1.000e-02, -4.260e-01,  2.638e+00],
#        [ 2.000e+00,  2.700e-02, -4.070e-01,  2.693e+00],
#        [ 3.000e+00,  8.300e-02, -1.800e-01,  2.805e+00],
#        [ 4.000e+00,  4.800e-02,  1.700e-02,  2.804e+00],
#        [ 5.000e+00, -1.120e-01, -2.910e-01,  2.791e+00],
#        [ 6.000e+00, -1.820e-01, -4.670e-01,  2.728e+00],
#        [ 7.000e+00, -9.700e-02, -4.830e-01,  2.564e+00],
#        [ 8.000e+00, -6.800e-02, -4.870e-01,  2.513e+00],
#        [ 9.000e+00,  2.200e-01, -2.800e-01,  2.772e+00],
#        [ 1.000e+01,  3.190e-01, -4.260e-01,  2.593e+00],
#        [ 1.100e+01,  1.770e-01, -4.010e-01,  2.391e+00],
#        [ 1.200e+01,  1.010e-01, -4.120e-01,  2.317e+00],
#        [ 1.300e+01, -1.030e-01, -4.610e-01,  2.603e+00],
#        [ 1.400e+01, -4.100e-02, -6.130e-01,  2.166e+00],
#        [ 1.500e+01, -5.700e-02, -8.340e-01,  2.052e+00],
#        [ 1.600e+01, -8.700e-02, -8.240e-01,  1.993e+00],
# ...

# %%
frame_num = 20
xs = frames[frame_num][:,1]
ys = frames[frame_num][:,2]
zs = frames[frame_num][:,3]

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter(xs[:],ys[:],zs[:])
# Out:
# <img src="data:image/png;base64,..." width="639.85">
